# %% [markdown]
# #
# # <center> A New Star of the City</center>
# #

# %% [markdown]
# #### <center>Daniel H</center>
#
#
#
#
# #### <center>Publish date: 1/5/2020</center>
#
#
#
# #### <center>Contact: info.qq.com</center>

# %% [markdown]
# ## Table of content
#    Abstract
# 1. Background
# 2. Introduction
# 3. Methodology
# 4. Results
# 5. Discussion
# 6. Conclusions
# 7. References

# %% [markdown]
# ##  Abstract

# %% [markdown]
#   The successful business man Boss ZHANG moved to In the city of Toronto, Canana recently. He planed to establish a new business here and continue his Cafe business.So he invited me to see where is the best place for hisb new shop.By studying the city's current business environment, I give him some suggetion. Here they are.

# %% [markdown]
# ## 1. Background

# %% [markdown]
#   Toronto is a big city. There are a lot of businesses already there. To find a good place to open a new shop, we need to where it the best place. For the Cafe shop, it must be in a busy area where more similar shops around.
#   So the final task is to find for which neighborhood we have more Cafe shops than anywhere else.

# %% [markdown]
# ## 2. Introduction

# %% [markdown]
# We start from get all data we need.
# Firstly, we need to know the neighborhoods of Toronto.
# Secondly, current business situation of the city.

# %% [markdown]
# #### 2.1 Data acquisition and cleaning

# %% [markdown]
#  For neighborhoods of Toronto.
#  We get the data from https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_H.

# %% [markdown]
# After download the data, we put it in ad DataFram. It is something like that:
# ![image.png](attachment:image.png)
# You can see many empty data and some duplicated ones. We deleted the lines with empty zip code, put all neighborhoods under it's zip code.

# %% [markdown]
# After the operation we get:
# ![image.png](attachment:image.png)

# %% [markdown]
# For all the post codes, we get the location:
# ![image.png](attachment:image.png)

# %% [markdown]
# We combine the post code together with the location:
# ![image.png](attachment:image.png)

# %% [markdown]
# For business information. We get the data from http://cocl.us/Geospatial_data
# ![image.png](attachment:image.png)
# The photo shows all the interest points of the city.

# %% [markdown]
# We can get the information and show like this:
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2.2 Exploratory Data Analysis

# %% [markdown]
# We find the location of placees, which are marked as "[latitude, longitude]".
# With the Kmeans methodology, we find the top 1 busy area.
# ![image.png](attachment:image.png)
# Here is the list we can see Cafe is in Top 5.

# %% [markdown]
# Find the best area is Toronto Downtown:
# ![image.png](attachment:image.png)
# Comparing with lower one:
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. Methodology

# %% [markdown]
# We use Python to deal with our problem, because it is powerful and convenient.
# We use Kmeans to find the best place, because it is easy to run with a very good result.

# %% [markdown]
# ## 4. Results

# %% [markdown]
# Finally we find the right place is within Toronto Downtown, as showed in the photo. Shown in purple color.
# Because here we find more shops which means the traffic must be good.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5. Discussion

# %% [markdown]
# We use Kmeans to find the place. Because we need to set the original centroid randomly, so the results maybe some kind of inaccurate. But this seems already good enough.

# %% [markdown]
# ## 6. Conclusions

# %% [markdown]
# From the study, we know the busiest area of the city, which has more attractive shops. We recommend Boss ZHANG to look for a room to rent with the area.

# %% [markdown]
# ## 7. References

# %% [markdown]
# 1. The data from: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_H
# 2. We use Foursquare to get the information.
